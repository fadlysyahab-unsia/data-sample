# %% [markdown]
# <a href="https://colab.research.google.com/github/fadlysyahab-unsia/data-sample/blob/main/Baca_csv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/fadlysyahab-unsia/data-sample/refs/heads/main/dataexample2.csv"
# Read the CSV file

from IPython.display import display
#tampilkan seluruh data

bacadata = pd.read_csv(url, sep=';',header=1, names=["A", "B", "C", "D", "E", "F", "G", "H", "I", "J"])
#header = lewati baris pertama, dibaca sbg header
#names = memberi nama kolom

#bacadata.head()
# View the first 5 rows

display(bacadata)
#tampilkan seluruh data

list_kolom = bacadata.columns.tolist()
# Mencetak hasil
# print(list_kolom)
# Jumlah_Proyek = bacadata['G'].sum()
# print(f"Proyek: {Jumlah_Proyek}")

# #Jumlah_Investasi = bacadata['E'].sum()
# #print(f"Tambahan Investasi : {Jumlah_Investasi}")

# Jumlah_TKI = bacadata['H'].sum()
# print(f"Jumlah TKI : {Jumlah_TKI}")

# Jumlah_TKA = bacadata['I'].sum()
# print(f"Jumlah TKI : {Jumlah_TKA}")
# Out:
#                                                     A  \
# 0   Industri Logam Dasar, Barang Logam, Bukan Mesi...
# 1                                           Kehutanan
# 2                            Perdagangan dan Reparasi
# 3          Tanaman Pangan, Perkebunan, dan Peternakan
# 4         Perumahan, Kawasan Industri dan Perkantoran
# 5             Transportasi, Gudang dan Telekomunikasi
# 6   Industri Logam Dasar, Barang Logam, Bukan Mesi...
# 7                                    Industri Makanan
# 8   Industri Logam Dasar, Barang Logam, Bukan Mesi...
# 9                                    Industri Makanan
# 10         Tanaman Pangan, Perkebunan, dan Peternakan
# 11                                   Industri Makanan
# 12                                   Industri Makanan
# 13         Tanaman Pangan, Perkebunan, dan Peternakan
# 14         Tanaman Pangan, Perkebunan, dan Peternakan
# 15                                          Kehutanan
# ...
